# %% [markdown]
# # PYTHON CAC-2

# %% [markdown]
# # Exploratory Data Analysis
#
# The team must identify a Domain related to Lavasa (Student Life, Traveling Preferences, Food Preferences...), create a unique problem statement associated with the domain, and determine the attributes associated with the problem.
#
# Collect data using various techniques, perform Exploratory Data Analysis (with the help of Python), and Present the Key insights obtained from the analysis in a Chart.

# %% [markdown]
# DOMAIN:- STUDENT'S LIFE IN THE COLLEGE CAMPUS

# %% [markdown]
# PROBLEM:-   MANAGEMENT BETWEEN ACADEMICS AND EXTRA CURRICULAR

# %% [markdown]
# Install Python Libraries

# %%
# pip install pandas

# %%
# pip install numpy

# %%
# pip install matplotlib

# %% [markdown]
# IMPORT PYTHON LIBRARIES

# %% [markdown]
# Pandas and Numpy have been used for Data Manipulation and Numerical Calculations
#
# Matplotlib and Seaborn have been used for Data visualizations.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING THE DATASET

# %%
#READING THE DATASET
pd.read_excel("Students' Life at Christ (Responses).xlsx")
# Out:
#                   Timestamp                 Name Department  GENDER    YEAR  \
# 0   2023-10-10 21:20:21.933            Stuty Das     MSC DS  FEMALE   FIRST
# 1   2023-10-10 21:32:57.896      Aryan Manchanda     BSC DS    MALE   FIRST
# 2   2023-10-10 22:16:09.915         Anju Mathew         LLB  FEMALE  SECOND
# 3   2023-10-10 22:17:36.971        Gracy Rathaur        LLB  FEMALE   THIRD
# 4   2023-10-10 22:35:12.016        Sreelakshmi G        BBA  FEMALE   FIRST
# ..                      ...                  ...        ...     ...     ...
# 397 2023-10-17 22:30:13.221  Rhea Eleanor Rhine         BBA  FEMALE   THIRD
# 398 2023-10-17 22:31:36.111   Pariska Nagvenkar         BBA  FEMALE  SECOND
# 399 2023-10-17 22:33:12.435        Vatsal Sharma        LLB    MALE  SECOND
# 400 2023-10-17 22:33:20.940               Rachel        MBA  FEMALE   FIRST
# 401 2023-10-17 22:34:02.656        Shilpi Singh        BCOM  FEMALE  SECOND
#
#     Do you follow a Semester or Trimester System?  \
# 0                                       Trimester
# 1                                        Semester
# 2                                        Semester
# 3                                        Semester
# 4                                        Semester
# ..                                            ...
# 397                                      Semester
# 398                                      Semester
# 399                                      Semester
# 400                                     Trimester
# 401                                      Semester
#
#     Do you participate in any extra curricular activities?  \
# 0                                                   No
# 1                                                  YES
# 2                                                  YES
# 3                                                  YES
# 4                                                   No
# ..                                                 ...
# 397                                                 No
# 398                                                 No
# 399                                                YES
# 400                                                YES
# 401                                                 No
#
#     If No,  how do you spend your time after college hours?  \
# 0                                              Cooking
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                       Academic works
# ..                                                 ...
# 397                              Hang out with friends
# 398                                     Academic works
# 399                                                NaN
# 400                                                NaN
# 401                                            Cooking
#
#     IF YES, select the following  \
# 0                            NaN
# 1                         SPORTS
# 2                            SWO
# 3                          CLUBS
# 4                            NaN
# ..                           ...
# 397                          NaN
# 398                          NaN
# 399                        CLUBS
# 400                          SWO
# 401                          NaN
#
#     Are you able to balance your academics with extracurricular?  \
# 0                                                  NaN
# 1                                                   No
# 2                                                  Yes
# 3                                                Maybe
# 4                                                  NaN
# ..                                                 ...
# 397                                              Maybe
# 398                                                 No
# 399                                              Maybe
# 400                                              Maybe
# 401                                                NaN
#
#      How do you rate your time management\n(On the scale of 5)  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 397                                                  3
# 398                                                  3
# 399                                                  3
# 400                                                  2
# 401                                                  3
#
#     Do you think participation in extracurricular affect your academic performance?  \
# 0                                                  Yes
# 1                                                Maybe
# 2                                                Maybe
# 3                                                  Yes
# 4                                                Maybe
# ..                                                 ...
# 397                                                 No
# 398                                                Yes
# 399                                                Yes
# 400                                              Maybe
# 401                                              Maybe
#
#     Do you think extracurricular activities should be open after 10:30?  \
# 0                                                Maybe
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                Maybe
# ..                                                 ...
# 397                                                Yes
# 398                                              Maybe
# 399                                                 No
# 400                                                 No
# 401                                              Maybe
#
#     Do you think everyone is getting equal chance in participating in extracurricular activities?  \
# 0                                                Maybe
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  NaN
# ..                                                 ...
# 397                                                 No
# 398                                                Yes
# 399                                                Yes
# 400                                                Yes
# 401                                                 No
#
#     Do you get exposure in extracurricular activities  \
# 0                                                 NaN
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 NaN
# ..                                                ...
# 397                                                No
# 398                                                No
# 399                                               Yes
# 400                                               Yes
# 401                                             Maybe
#
#     If yes, select one of the following  If No, select the reason
# 0                                   NaN  Hectic Academic schedule
# 1                       Proper Training                       NaN
# 2                       Good facilities                       NaN
# 3                       Good facilities                       NaN
# 4                                   NaN  Hectic Academic schedule
# ..                                  ...                       ...
# 397                                 NaN        Lack of facilities
# 398                                 NaN  Hectic Academic schedule
# 399                     Good facilities                       NaN
# 400                     Proper Training                       NaN
# 401                                 NaN                       NaN
#
# [402 rows x 17 columns]

# %%
data = pd.read_excel("Students' Life at Christ (Responses).xlsx")

# %% [markdown]
# DATA CLEANING

# %%
data["GENDER"].replace({"Male": "MALE", "Female": "FEMALE","FeMALE":"FEMALE"}, inplace=True)

# %% [markdown]
# ANALYZING THE DATASET

# %%
data.dtypes
# Out:
# Timestamp                                                                                        datetime64[ns]
# Name                                                                                                     object
# Department                                                                                               object
# GENDER                                                                                                   object
# YEAR                                                                                                     object
# Do you follow a Semester or Trimester System?                                                            object
# Do you participate in any extra curricular activities?                                                   object
# If No,  how do you spend your time after college hours?                                                  object
# IF YES, select the following                                                                             object
# Are you able to balance your academics with extracurricular?                                             object
# How do you rate your time management\n(On the scale of 5)                                                 int64
# Do you think participation in extracurricular affect your academic performance?                          object
# Do you think extracurricular activities should be open after 10:30?                                      object
# Do you think everyone is getting equal chance in participating in extracurricular activities?            object
# Do you get exposure in extracurricular activities                                                        object
# If yes, select one of the following                                                                      object
# If No, select the reason                                                                                 object
# dtype: object

# %%
data.count()
# Out:
# Timestamp                                                                                        402
# Name                                                                                             402
# Department                                                                                       402
# GENDER                                                                                           402
# YEAR                                                                                             402
# Do you follow a Semester or Trimester System?                                                    402
# Do you participate in any extra curricular activities?                                           402
# If No,  how do you spend your time after college hours?                                          235
# IF YES, select the following                                                                     227
# Are you able to balance your academics with extracurricular?                                     368
# How do you rate your time management\n(On the scale of 5)                                        402
# Do you think participation in extracurricular affect your academic performance?                  398
# Do you think extracurricular activities should be open after 10:30?                              398
# Do you think everyone is getting equal chance in participating in extracurricular activities?    394
# Do you get exposure in extracurricular activities                                                381
# If yes, select one of the following                                                              217
# If No, select the reason                                                                         226
# dtype: int64

# %%
#DISPLAYING THE TOP 5 OBSERVATION
data.head()
# Out:
#                 Timestamp             Name Department  GENDER    YEAR  \
# 0 2023-10-10 21:20:21.933        Stuty Das     MSC DS  FEMALE   FIRST
# 1 2023-10-10 21:32:57.896  Aryan Manchanda     BSC DS    MALE   FIRST
# 2 2023-10-10 22:16:09.915     Anju Mathew         LLB  FEMALE  SECOND
# 3 2023-10-10 22:17:36.971    Gracy Rathaur        LLB  FEMALE   THIRD
# 4 2023-10-10 22:35:12.016    Sreelakshmi G        BBA  FEMALE   FIRST
#
#   Do you follow a Semester or Trimester System?  \
# 0                                     Trimester
# 1                                      Semester
# 2                                      Semester
# 3                                      Semester
# 4                                      Semester
#
#   Do you participate in any extra curricular activities?  \
# 0                                                 No
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                 No
#
#   If No,  how do you spend your time after college hours?  \
# 0                                            Cooking
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                     Academic works
#
#   IF YES, select the following  \
# 0                          NaN
# 1                       SPORTS
# 2                          SWO
# 3                        CLUBS
# 4                          NaN
#
#   Are you able to balance your academics with extracurricular?  \
# 0                                                NaN
# 1                                                 No
# 2                                                Yes
# 3                                              Maybe
# 4                                                NaN
#
#    How do you rate your time management\n(On the scale of 5)  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#   Do you think participation in extracurricular affect your academic performance?  \
# 0                                                Yes
# 1                                              Maybe
# 2                                              Maybe
# 3                                                Yes
# 4                                              Maybe
#
#   Do you think extracurricular activities should be open after 10:30?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                              Maybe
#
#   Do you think everyone is getting equal chance in participating in extracurricular activities?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                NaN
#
#   Do you get exposure in extracurricular activities  \
# 0                                               NaN
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               NaN
#
#   If yes, select one of the following  If No, select the reason
# 0                                 NaN  Hectic Academic schedule
# 1                     Proper Training                       NaN
# 2                     Good facilities                       NaN
# 3                     Good facilities                       NaN
# 4                                 NaN  Hectic Academic schedule

# %%
#DISPLAYING THE LAST 5 OBSERVATION
data.tail()
# Out:
#                   Timestamp                 Name Department  GENDER    YEAR  \
# 397 2023-10-17 22:30:13.221  Rhea Eleanor Rhine         BBA  FEMALE   THIRD
# 398 2023-10-17 22:31:36.111   Pariska Nagvenkar         BBA  FEMALE  SECOND
# 399 2023-10-17 22:33:12.435        Vatsal Sharma        LLB    MALE  SECOND
# 400 2023-10-17 22:33:20.940               Rachel        MBA  FEMALE   FIRST
# 401 2023-10-17 22:34:02.656        Shilpi Singh        BCOM  FEMALE  SECOND
#
#     Do you follow a Semester or Trimester System?  \
# 397                                      Semester
# 398                                      Semester
# 399                                      Semester
# 400                                     Trimester
# 401                                      Semester
#
#     Do you participate in any extra curricular activities?  \
# 397                                                 No
# 398                                                 No
# 399                                                YES
# 400                                                YES
# 401                                                 No
#
#     If No,  how do you spend your time after college hours?  \
# 397                              Hang out with friends
# 398                                     Academic works
# 399                                                NaN
# 400                                                NaN
# 401                                            Cooking
#
#     IF YES, select the following  \
# 397                          NaN
# 398                          NaN
# 399                        CLUBS
# 400                          SWO
# 401                          NaN
#
#     Are you able to balance your academics with extracurricular?  \
# 397                                              Maybe
# 398                                                 No
# 399                                              Maybe
# 400                                              Maybe
# 401                                                NaN
#
#      How do you rate your time management\n(On the scale of 5)  \
# 397                                                  3
# 398                                                  3
# 399                                                  3
# 400                                                  2
# 401                                                  3
#
#     Do you think participation in extracurricular affect your academic performance?  \
# 397                                                 No
# 398                                                Yes
# 399                                                Yes
# 400                                              Maybe
# 401                                              Maybe
#
#     Do you think extracurricular activities should be open after 10:30?  \
# 397                                                Yes
# 398                                              Maybe
# 399                                                 No
# 400                                                 No
# 401                                              Maybe
#
#     Do you think everyone is getting equal chance in participating in extracurricular activities?  \
# 397                                                 No
# 398                                                Yes
# 399                                                Yes
# 400                                                Yes
# 401                                                 No
#
#     Do you get exposure in extracurricular activities  \
# 397                                                No
# 398                                                No
# 399                                               Yes
# 400                                               Yes
# 401                                             Maybe
#
#     If yes, select one of the following  If No, select the reason
# 397                                 NaN        Lack of facilities
# 398                                 NaN  Hectic Academic schedule
# 399                     Good facilities                       NaN
# 400                     Proper Training                       NaN
# 401                                 NaN                       NaN

# %%
#DISPLAYING THE DATA TYPE AND THE INFORMATION ABOUT THE DATA SET
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 17 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Timestamp                                                                                      402 non-null    datetime64[ns]
#  1   Name                                                                                           402 non-null    object
#  2   Department                                                                                     402 non-null    object
#  3   GENDER                                                                                         402 non-null    object
#  4   YEAR                                                                                           402 non-null    object
#  5   Do you follow a Semester or Trimester System?                                                  402 non-null    object
#  6   Do you participate in any extra curricular activities?                                         402 non-null    object
#  7   If No,  how do you spend your time after college hours?                                        235 non-null    object
#  8   IF YES, select the following                                                                   227 non-null    object
#  9   Are you able to balance your academics with extracurricular?                                   368 non-null    object
#  10  How do you rate your time management
# (On the scale of 5)                                       402 non-null    int64
#  11  Do you think participation in extracurricular affect your academic performance?                398 non-null    object
#  12  Do you think extracurricular activities should be open after 10:30?                            398 non-null    object
#  13  Do you think everyone is getting equal chance in participating in extracurricular activities?  394 non-null    object
#  14  Do you get exposure in extracurricular activities                                              381 non-null    object
#  15  If yes, select one of the following                                                            217 non-null    object
#  16  If No, select the reason                                                                       226 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(15)
# memory usage: 53.5+ KB

# %%
#CHECKING THE DUPLICATION
data.nunique()
# Out:
# Timestamp                                                                                        402
# Name                                                                                             402
# Department                                                                                        11
# GENDER                                                                                             2
# YEAR                                                                                               5
# Do you follow a Semester or Trimester System?                                                      2
# Do you participate in any extra curricular activities?                                             2
# If No,  how do you spend your time after college hours?                                            4
# IF YES, select the following                                                                       5
# Are you able to balance your academics with extracurricular?                                       3
# How do you rate your time management\n(On the scale of 5)                                          5
# Do you think participation in extracurricular affect your academic performance?                    3
# Do you think extracurricular activities should be open after 10:30?                                3
# Do you think everyone is getting equal chance in participating in extracurricular activities?      3
# Do you get exposure in extracurricular activities                                                  3
# If yes, select one of the following                                                                3
# If No, select the reason                                                                           5
# dtype: int64

# %%
#MISSING VALUE CALCULATION
data.isnull().sum()
# Out:
# Timestamp                                                                                          0
# Name                                                                                               0
# Department                                                                                         0
# GENDER                                                                                             0
# YEAR                                                                                               0
# Do you follow a Semester or Trimester System?                                                      0
# Do you participate in any extra curricular activities?                                             0
# If No,  how do you spend your time after college hours?                                          167
# IF YES, select the following                                                                     175
# Are you able to balance your academics with extracurricular?                                      34
# How do you rate your time management\n(On the scale of 5)                                          0
# Do you think participation in extracurricular affect your academic performance?                    4
# Do you think extracurricular activities should be open after 10:30?                                4
# Do you think everyone is getting equal chance in participating in extracurricular activities?      8
# Do you get exposure in extracurricular activities                                                 21
# If yes, select one of the following                                                              185
# If No, select the reason                                                                         176
# dtype: int64

# %%
#PERCENTAGE OF MISSING VALUE CALCULATION
data.isnull().sum()/(len(data))*100
# Out:
# Timestamp                                                                                         0.000000
# Name                                                                                              0.000000
# Department                                                                                        0.000000
# GENDER                                                                                            0.000000
# YEAR                                                                                              0.000000
# Do you follow a Semester or Trimester System?                                                     0.000000
# Do you participate in any extra curricular activities?                                            0.000000
# If No,  how do you spend your time after college hours?                                          41.542289
# IF YES, select the following                                                                     43.532338
# Are you able to balance your academics with extracurricular?                                      8.457711
# How do you rate your time management\n(On the scale of 5)                                         0.000000
# Do you think participation in extracurricular affect your academic performance?                   0.995025
# Do you think extracurricular activities should be open after 10:30?                               0.995025
# Do you think everyone is getting equal chance in participating in extracurricular activities?     1.990050
# Do you get exposure in extracurricular activities                                                 5.223881
# If yes, select one of the following                                                              46.019900
# If No, select the reason                                                                         43.781095
# dtype: float64

# %% [markdown]
# Statistics Summary

# %%
data.describe()
# Out:
#        How do you rate your time management\n(On the scale of 5)
# count                                         402.000000
# mean                                            2.845771
# std                                             0.856889
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000

# %%
data.describe(include="all")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_60320\3772400700.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include="all")
#                          Timestamp       Name Department GENDER   YEAR  \
# count                          402        402        402    402    402
# unique                         402        402         11      2      5
# top     2023-10-10 21:20:21.933000  Stuty Das        LLB   MALE  FIRST
# freq                             1          1        118    209    181
# first   2023-10-10 21:20:21.933000        NaN        NaN    NaN    NaN
# last    2023-10-17 22:34:02.656000        NaN        NaN    NaN    NaN
# mean                           NaN        NaN        NaN    NaN    NaN
# std                            NaN        NaN        NaN    NaN    NaN
# min                            NaN        NaN        NaN    NaN    NaN
# 25%                            NaN        NaN        NaN    NaN    NaN
# 50%                            NaN        NaN        NaN    NaN    NaN
# 75%                            NaN        NaN        NaN    NaN    NaN
# max                            NaN        NaN        NaN    NaN    NaN
#
#        Do you follow a Semester or Trimester System?  \
# count                                            402
# unique                                             2
# top                                         Semester
# freq                                             305
# first                                            NaN
# last                                             NaN
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#        Do you participate in any extra curricular activities?  \
# count                                                 402
# unique                                                  2
# top                                                   YES
# freq                                                  215
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        If No,  how do you spend your time after college hours?  \
# count                                                 235
# unique                                                  4
# top                                        Academic works
# freq                                                  132
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        IF YES, select the following  \
# count                           227
# unique                            5
# top                           CLUBS
# freq                             78
# first                           NaN
# last                            NaN
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#        Are you able to balance your academics with extracurricular?  \
# count                                                 368
# unique                                                  3
# top                                                 Maybe
# freq                                                  161
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         How do you rate your time management\n(On the scale of 5)  \
# count                                          402.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             2.845771
# std                                              0.856889
# min                                              1.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              3.000000
# max                                              5.000000
#
#        Do you think participation in extracurricular affect your academic performance?  \
# count                                                 398
# unique                                                  3
# top                                                   Yes
# freq                                                  178
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Do you think extracurricular activities should be open after 10:30?  \
# count                                                 398
# unique                                                  3
# top                                                   Yes
# freq                                                  196
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Do you think everyone is getting equal chance in participating in extracurricular activities?  \
# count                                                 394
# unique                                                  3
# top                                                   Yes
# freq                                                  193
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Do you get exposure in extracurricular activities  \
# count                                                381
# unique                                                 3
# top                                                  Yes
# freq                                                 184
# first                                                NaN
# last                                                 NaN
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        If yes, select one of the following  If No, select the reason
# count                                  217                       226
# unique                                   3                         5
# top                        Good facilities  Hectic Academic schedule
# freq                                   120                       160
# first                                  NaN                       NaN
# last                                   NaN                       NaN
# mean                                   NaN                       NaN
# std                                    NaN                       NaN
# min                                    NaN                       NaN
# 25%                                    NaN                       NaN
# 50%                                    NaN                       NaN
# 75%                                    NaN                       NaN
# max                                    NaN                       NaN

# %% [markdown]
# DISTRIBUTION

# %%
#HISTROGRAM CHART FOR TIME MANAGEMENT
import numpy as np


for col in data.columns:
    if data[col].dtype in ['int64', 'float64']:  # Check if the data type is numerical
        print(col)
        print('Skew:', round(data[col].skew(), 2))
        plt.figure(figsize=(15, 4))
        plt.subplot(1, 2, 1)
        data[col].hist(grid=False)
        plt.ylabel('count')
        plt.subplot(1, 2, 2)
        sns.boxplot(x=data[col])
        plt.show()
# Out:
# How do you rate your time management
# (On the scale of 5)
# Skew: -0.1

# %% [markdown]
# From the graph above, we concluded that most of the students rate their time management skills as not so appropriate.

# %% [markdown]
# CATEGORICAL DISTRIBUTION

# %% [markdown]
# 1.YEARWISE DISTRIBUTION

# %%
#PIE CHART FOR YEARWISE DISTRIBUTION
import numpy as np

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    group_counts = df[colname].value_counts()
    group_counts.plot(kind='pie', colors=sns.color_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale), autopct='%1.1f%%')
    plt.gca().set_aspect("equal")  # Ensure the pie chart is a circle
    plt.title(colname)
    return

categorical_histogram(data, 'YEAR')
plt.show()

# %% [markdown]
# It is quite evident that the first years participation in the survey was the maximum as compared to the others, while students of fifth year were the least.

# %% [markdown]
# 2.GENDERWISE DISTRIBUTION

# %%
import numpy as np

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
    plt.gca().spines[['top', 'right',]].set_visible(False)
    return plt

chart = categorical_histogram(data, 'GENDER')
plt.show()  # Show the chart

# %% [markdown]
# Although, the participation from both males and females are impressive, but still responses from males have an upper edge in comparison to females.

# %% [markdown]
# 3.TRIMESTERWISE/SEMESTERWISE DISTRIBUTION

# %%
import numpy as np

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    df.groupby(colname).size().plot(kind='bar', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
    plt.gca().spines[['top', 'right',]].set_visible(False)
    return plt

chart = categorical_histogram(data, 'Do you follow a Semester or Trimester System?')
plt.show()  # Show the bar graph

# %% [markdown]
# It's clearly evident that most of the courses in Christ University has a semester based pattern.

# %% [markdown]
# 4.PARTICIPATION IN EXTRA CURRICULAR ACTIVITIES

# %%
import numpy as np


def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return

chart = categorical_histogram(data, *['Do you participate in any extra curricular activities?'], **{})
chart

# %% [markdown]
# It's surprising to conclude that there is no significant difference between the no. students who partici[ate and not participate in extra curricular activities.]

# %% [markdown]
# 5. SEMESTER/TRIMESTERWISE PARTICIPATION IN EXTRA-CURRICULAR ACTIVITIES

# %%
import numpy as np

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return

chart = heatmap(data, *['Do you follow a Semester or Trimester System?', 'Do you participate in any extra curricular activities?'], **{})
chart

# %% [markdown]
# This heatmap indicates that the students that have trimesters are unable to participate in co-curricular activites while the semester students are actively participating in such activites, which indirectly hints at the insufficient time with the former students.

# %% [markdown]
# 6.HEATMAP OF THE TRIMESTER/SEMESTER BASED ON YEARWISE

# %%
import numpy as np

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return 

chart = heatmap(data, *['YEAR', 'Do you follow a Semester or Trimester System?'], **{})
chart

# %% [markdown]
# This chart is segregating the semester/trimester depedending on the year the students are currently enrolled in.
# For instance: the third,fourth,fifth year don't have any trimesters.

# %% [markdown]
# 7.HEATMAP OF THE YEARWISE BASED ON GENDER

# %%
import numpy as np

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(8 * figscale, 8 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return 

chart = heatmap(data, *['GENDER', 'YEAR'], **{})
chart

# %% [markdown]
# Males from the first year have responded the most, while females from the fifth year have responded the least.
